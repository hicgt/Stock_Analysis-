# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from stocker import Stocker

# %%
apple = Stocker('AAPL')
# Out:
# AAPL Stocker Initialized. Data covers 1980-12-12 to 2018-03-27.

# %%
stock_history = apple.stock
stock_history.head()
# Out:
#         Date   Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# 0 1980-12-12  28.75  28.87  28.75  28.75  2093900.0          0.0          1.0
# 1 1980-12-15  27.38  27.38  27.25  27.25   785200.0          0.0          1.0
# 2 1980-12-16  25.37  25.37  25.25  25.25   472000.0          0.0          1.0
# 3 1980-12-17  25.87  26.00  25.87  25.87   385900.0          0.0          1.0
# 4 1980-12-18  26.63  26.75  26.63  26.63   327900.0          0.0          1.0
#
#    Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume         ds  \
# 0   0.422706   0.424470  0.422706    0.422706  117258400.0 1980-12-12
# 1   0.402563   0.402563  0.400652    0.400652   43971200.0 1980-12-15
# 2   0.373010   0.373010  0.371246    0.371246   26432000.0 1980-12-16
# 3   0.380362   0.382273  0.380362    0.380362   21610400.0 1980-12-17
# 4   0.391536   0.393300  0.391536    0.391536   18362400.0 1980-12-18
#
#           y  Daily Change
# 0  0.422706      0.000000
# ...

# %%
apple.plot_stock()
# Out:
# Maximum Adj. Close = 181.72 on 2018-03-12.
# Minimum Adj. Close = 0.16 on 1982-07-08.
# Current Adj. Close = 168.34 on 2018-03-27.

# %%
apple.plot_stock(start_date = '2016-01-03',  end_date = '2018-03-20',  stats = ['Daily Change', 'Adj. Volume'],  plot_type='pct')
# Out:
# Maximum Daily Change = 8.20 on 2018-02-06.
# Minimum Daily Change = -6.18 on 2017-06-09.
# Current Daily Change = -5.34 on 2018-03-27.
#
# Maximum Adj. Volume = 133369674.00 on 2016-01-27.
# Minimum Adj. Volume = 11475922.00 on 2016-11-25.
# Current Adj. Volume = 38962839.00 on 2018-03-27.

# %%
apple.buy_and_hold(start_date='2001-03-13', nshares=100)
# Out:
# AAPL Total buy and hold profit from 2001-03-13 to 2018-03-27 for 100 shares = $16712.75

# %%
model, model_data = apple.create_prophet_model()

# %%
model.plot_components(model_data)
plt.show()
