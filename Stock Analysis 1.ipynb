# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from stocker import Stocker

# %%
microsoft = Stocker('MSFT')
# Out:
# MSFT Stocker Initialized. Data covers 1986-03-13 to 2018-03-27.

# %%
stock_history = microsoft.stock

# %%
microsoft.plot_stock()
# Out:
# Maximum Adj. Close = 96.77 on 2018-03-12.
# Minimum Adj. Close = 0.06 on 1986-03-24.
# Current Adj. Close = 89.47 on 2018-03-27.

# %%
microsoft.buy_and_hold(start_date='1986-03-13', end_date='2018-01-16', nshares=100)
# Out:
# MSFT Total buy and hold profit from 1986-03-13 to 2018-01-16 for 100 shares = $8829.11

# %%
model, model_data = microsoft.create_prophet_model()

# %%
microsoft.changepoint_date_analysis(search = 'Microsoft profit')
# Out:
#  Top Related Queries:
#
#                   query  value
# 0  microsoft non profit    100
# 1      microsoft office     50
# 2                 apple     27
# 3         microsoft 365     22
# 4     microsoft revenue     19
#
#  Rising Related Queries:
#
#                    query   value
# 0  microsoft profit 2015  211300
# 1           gross profit     100
# 2          microsoft 365      70
# 3   microsoft non profit      50
# /Users/hic/stocker.py:789: FutureWarning:
# .resample() is now a deferred operation
# You called reset_index(...) on this deferred object which materialized it into a dataframe
# by implicitly taking the mean.  Use .resample(...).mean() instead
#   trends = trends.reset_index(level=0)
