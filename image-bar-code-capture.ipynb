# %% [raw]
# print hello

# %%
from pyzbar.pyzbar import decode
import cv2

# %%
image = cv2.imread('/users/hic/Downloads/lm1.png')

# %%
# %matplotlib inline

# %%
cv2.imshow('image',image)

# %%
from matplotlib import pyplot as plt
plt.imshow(image, cmap = 'gray', interpolation = 'bicubic')

# %%
decode(image)
# Out:
# [Decoded(data='Landmark 1', type='QRCODE', rect=Rect(left=16, top=16, width=168, height=168))]
